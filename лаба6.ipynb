# %%
import matplotlib.pyplot as plt
celsius =[[-67.0],[-34.0],[0],[34.0],[54.0],[67.0],[100]]
fahrenheit=[[-88.6],[-29.2],[32.0],[93.2],[129.2],[152.6],[212.0]]
plt.figure(figsize=(15,8), dpi=50)
plt.scatter(celsius, fahrenheit, label ='входные значения', color='green', marker='$f$');
plt.xlabel('celsius')
plt.legend()
plt.grid(True)
plt.show()

for c,f in zip(celsius, fahrenheit):
    print(f'цельсия{c}= фаренгейт {f}')
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    lr.fit(celsius, fahrenheit)
    lr.predict([[256],[123]])
    lr.coef_
    lr.intercept_
    celsius_test= [[-50],[10],[30],[20],[10],[70],[87]]
    fahrenheit_test = lr.predict(celsius_test)
    fahrenheit_test
# Out:
# цельсия[-67.0]= фаренгейт [-88.6]
# цельсия[-34.0]= фаренгейт [-29.2]
# цельсия[0]= фаренгейт [32.0]
# цельсия[34.0]= фаренгейт [93.2]
# цельсия[54.0]= фаренгейт [129.2]
# цельсия[67.0]= фаренгейт [152.6]
# цельсия[100]= фаренгейт [212.0]

# %%
for c,f in zip(celsius, fahrenheit):
    print(f'цельсия{c}= фаренгейт {f}')
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    lr.fit(celsius, fahrenheit)
    lr.predict([[256],[123]])
    lr.coef_
    lr.intercept_
    celsius_test= [[-50],[10],[30],[20],[10],[70],[87]]
    fahrenheit_test = lr.predict(celsius_test)
    fahrenheit_test
# Out:
# цельсия[-67.0]= фаренгейт [-88.6]
# цельсия[-34.0]= фаренгейт [-29.2]
# цельсия[0]= фаренгейт [32.0]
# цельсия[34.0]= фаренгейт [93.2]
# цельсия[54.0]= фаренгейт [129.2]
# цельсия[67.0]= фаренгейт [152.6]
# цельсия[100]= фаренгейт [212.0]

# %%
for c,f in zip(celsius_test, fahrenheit_test):
  print(f'цельсия{c} фаренгейта{f}')
import numpy as np

x_range = np.arange(-70,120)
y_range = x_range*1.8+32

plt.figure(figsize=(15,8), dpi=200)
plt.plot(x_range, y_range, label='уравнение', linewidth='1' )
plt.scatter(celsius, fahrenheit, label ='входные значения', color='green');
plt.scatter(celsius_test, fahrenheit_test, label ='предсказанное значеие', color='blue');
plt.ylabel('Цельсия')
plt.xlabel('Фаренгейта')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# цельсия[-50] фаренгейта[-58.]
# цельсия[10] фаренгейта[50.]
# цельсия[30] фаренгейта[86.]
# цельсия[20] фаренгейта[68.]
# цельсия[10] фаренгейта[50.]
# цельсия[70] фаренгейта[158.]
# цельсия[87] фаренгейта[188.6]

# %%
#1 задание обычной сложности
import matplotlib.pyplot as plt
kelvin =[[206.0],[239.0],[273],[307.0],[327.0],[340.0],[373]]
fahrenheit=[[-88.6],[-29.2],[32.0],[93.2],[129.2],[152.6],[212.0]]
plt.figure(figsize=(15,8), dpi=50)
plt.scatter(kelvin, fahrenheit, label ='входные значения', color='magenta', marker='$+$');
plt.xlabel('kelvin')
plt.legend()
plt.grid(True)
plt.show()

for c,f in zip(kelvin, fahrenheit):
    print(f'кельвинов{c}= фаренгейт {f}')
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    lr.fit(kelvin, fahrenheit)
    lr.predict([[256],[396]])
    lr.coef_
    lr.intercept_
    kelvin_test= [[-50],[10],[30],[20],[10],[70],[87]]
    fahrenheit_test = lr.predict(kelvin_test)
    fahrenheit_test
# Out:
# кельвинов[206.0]= фаренгейт [-88.6]
# кельвинов[239.0]= фаренгейт [-29.2]
# кельвинов[273]= фаренгейт [32.0]
# кельвинов[307.0]= фаренгейт [93.2]
# кельвинов[327.0]= фаренгейт [129.2]
# кельвинов[340.0]= фаренгейт [152.6]
# кельвинов[373]= фаренгейт [212.0]

# %%
#1 задание
kelvin =[[206.0],[239.0],[273],[307.0],[327.0],[340.0],[373]]
for k,f in zip(kelvin_test, fahrenheit_test):
  print(f'кельвина{k} фаренгейта{f}')
import numpy as np

x_range = np.arange(-70,400)
y_range = (x_range-273)*1.8+32
for c,f in zip(kelvin, fahrenheit):
    print(f'кельвинов{c}= фаренгейт {f}')
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    lr.fit(kelvin, fahrenheit)
    lr.predict([[256],[123]])
    lr.coef_
    lr.intercept_
    kelvin_test= [[-50],[10],[30],[20],[10],[70],[87]]
    fahrenheit_test = lr.predict(kelvin_test)
    fahrenheit_test
plt.figure(figsize=(15,8), dpi=200)
plt.plot(x_range, y_range, label='уравнение', linewidth='0.5' )
plt.scatter(kelvin, fahrenheit, label ='входные значения', color='magenta');
plt.scatter(kelvin_test, fahrenheit_test, label ='предсказанное значение', color='blue');
plt.xlabel('Кельвина')
plt.ylabel('Фаренгейта')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# кельвина[-50] фаренгейта[-549.4]
# кельвина[10] фаренгейта[-441.4]
# кельвина[30] фаренгейта[-405.4]
# кельвина[20] фаренгейта[-423.4]
# кельвина[10] фаренгейта[-441.4]
# кельвина[70] фаренгейта[-333.4]
# кельвина[87] фаренгейта[-302.8]
# кельвинов[206.0]= фаренгейт [-88.6]
# кельвинов[239.0]= фаренгейт [-29.2]
# кельвинов[273]= фаренгейт [32.0]
# кельвинов[307.0]= фаренгейт [93.2]
# кельвинов[327.0]= фаренгейт [129.2]
# кельвинов[340.0]= фаренгейт [152.6]
# кельвинов[373]= фаренгейт [212.0]

# %%
#2 задание
# !git clone https://github.com/Bloody-Zero/Kupriyanenko-Svetlana-Eduardovna-PI-311
# Out:
# Cloning into 'Kupriyanenko-Svetlana-Eduardovna-PI-311'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), done.

# %%
#3 задание
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()

x = np.array([-3, -2, -1, 0.1, 1 ,2 ,3])
y = np.array([9,4,1,0.1,1,4,9])

ax.plot(x, np.sin(x), color =(1.0,0.2,0.3),linestyle='-')
ax.plot(x, x+10, color='magenta', linestyle='-.')
ax.plot(x, np.cos(y), color='0.75')

# %%
#4 задание
import math

print(math.e,math.pi,math.isnan(0),math.factorial(7),math.gcd(7,256))
# Out:
# 2.718281828459045 3.141592653589793 False 5040 1

# %%
#пов сложность 1
